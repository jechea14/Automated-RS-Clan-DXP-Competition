# %%
import requests
import pandas as pd
import csv

skills = [

    {
        "id": 0,
        "name": "Attack" 
    },
    {
        "id": 1,
        "name": "Defense"
    },
    {
        "id": 2,
        "name": "Strength"
    },
    {
        "id": 3,
        "name": "Constitution"
    },
    {
        "id": 4,
        "name": "Ranged"
    },
    {
        "id": 5,
        "name": "Prayer"
    },
    {
        "id": 6,
        "name": "Magic"
    },
    {
        "id": 7,
        "name": "Cooking"
    },
    {
        "id": 8,
        "name": "Woodcutting"
    },
    {
        "id": 9,
        "name": "Flecthing"
    },
    {
        "id": 10,
        "name": "Fishing"
    },
    {
        "id": 11,
        "name": "Firemaking"
    },
    {
        "id": 12,
        "name": "Crafting"
    },
    {
        "id": 13,
        "name": "Smithing"
    },
    {
        "id": 14,
        "name": "Mining"
    },
    {
        "id": 15,
        "name": "Herblore"
    },
    {
        "id": 16,
        "name": "Agility"
    },
    {
        "id": 17,
        "name": "Thieving"
    },
    {
        "id": 18,
        "name": "Slayer"
    },
    {
        "id": 19,
        "name": "Farming"
    },
    {
        "id": 20,
        "name": "Runecrafting"
    },
    {
        "id": 21,
        "name": "Hunter"
    },
    {
        "id": 22,
        "name": "Construction"
    },
    {
        "id": 23,
        "name": "Summmoning"
    },
    {
        "id": 24,
        "name": "Dungeoneering"
    },
    {
        "id": 25,
        "name": "Divination"
    },
    {
        "id": 26,
        "name": "Invention"
    },
    {
        "id": 27,
        "name": "Archaeology"
    }
]
 
def myFunc(e):
  return e['id']
# print(skills[0]['name'])

r = requests.get('https://apps.runescape.com/runemetrics/profile/profile?user=icekrystalx')
data = r.json()
# print(data["skillvalues"])
player_name = data["name"]


skill_data = data["skillvalues"]
skill_data1 = data["skillvalues"]

skill_data.sort(key=myFunc)
skill_data1.sort(key=myFunc)

for i in range(0, len(skill_data)):
    skill_data[i]["skill"] = (skills[i]["name"])
print((skill_data))
# Out:
# [{'level': 99, 'xp': 709884951, 'rank': 38539, 'id': 0, 'skill': 'Attack'}, {'level': 99, 'xp': 1054063719, 'rank': 40055, 'id': 1, 'skill': 'Defense'}, {'level': 99, 'xp': 168885343, 'rank': 154084, 'id': 2, 'skill': 'Strength'}, {'level': 99, 'xp': 1139599610, 'rank': 47732, 'id': 3, 'skill': 'Constitution'}, {'level': 99, 'xp': 438440458, 'rank': 79421, 'id': 4, 'skill': 'Ranged'}, {'level': 99, 'xp': 167495429, 'rank': 78725, 'id': 5, 'skill': 'Prayer'}, {'level': 99, 'xp': 1235133936, 'rank': 31061, 'id': 6, 'skill': 'Magic'}, {'level': 99, 'xp': 148431608, 'rank': 117966, 'id': 7, 'skill': 'Cooking'}, {'level': 99, 'xp': 141694702, 'rank': 146327, 'id': 8, 'skill': 'Woodcutting'}, {'level': 99, 'xp': 145429073, 'rank': 100624, 'id': 9, 'skill': 'Flecthing'}, {'level': 99, 'xp': 229603578, 'rank': 86980, 'id': 10, 'skill': 'Fishing'}, {'level': 99, 'xp': 174332293, 'rank': 89937, 'id': 11, 'skill': 'Firemaking'}, {'level': 99, 'xp': 156751521, 'rank': 99303, 'id': 12, 'skill': '
# ...

# %%
df = pd.DataFrame(data=skill_data)
df
# Out:
#     level          xp    rank  id          skill
# 0      99   709884951   38532   0         Attack
# 1      99  1054063719   40060   1        Defense
# 2      99   168885343  154031   2       Strength
# 3      99  1139599610   47738   3   Constitution
# 4      99   438440458   79390   4         Ranged
# 5      99   167495429   78711   5         Prayer
# 6      99  1235133936   31064   6          Magic
# 7      99   148431608  117917   7        Cooking
# 8      99   141694702  146276   8    Woodcutting
# 9      99   145429073  100591   9      Flecthing
# 10     99   229603578   86948  10        Fishing
# 11     99   174332293   89909  11     Firemaking
# 12     99   156751521   99280  12       Crafting
# 13     99   239666080   48027  13       Smithing
# 14     99   338083879   51793  14         Mining
# 15    120  1044402873   57411  15       Herblore
# 16     99   167376049   86940  16        Agility
# 17     99  1043542095   24903  17       Thieving
# ...

# %%
a = {}

for i in range(0, len(skill_data)):
    a[skills[i]["name"]] = (skill_data[i]["xp"])

b = {"Name": player_name}
b.update(a)
b
# Out:
# {'Name': 'IceKrystalx',
#  'Attack': 709884951,
#  'Defense': 1054063719,
#  'Strength': 168885343,
#  'Constitution': 1139599610,
#  'Ranged': 438440458,
#  'Prayer': 167495429,
#  'Magic': 1235133936,
#  'Cooking': 148431608,
#  'Woodcutting': 141694702,
#  'Flecthing': 145429073,
#  'Fishing': 229603578,
#  'Firemaking': 174332293,
#  'Crafting': 156751521,
#  'Smithing': 239666080,
#  'Mining': 338083879,
#  'Herblore': 1044402873,
#  'Agility': 167376049,
#  'Thieving': 1043542095,
#  'Slayer': 1280489665,
#  'Farming': 1145339197,
#  'Runecrafting': 136534895,
#  'Hunter': 142332293,
#  'Construction': 153621208,
#  'Summmoning': 192895420,
#  'Dungeoneering': 2000000000,
#  'Divination': 142876467,
#  'Invention': 933745357,
#  'Archaeology': 1163031646}

# %%
df = pd.DataFrame(data=b, index=[0])
df
# Out:
#           Name     Attack     Defense   Strength  Constitution     Ranged  \
# 0  IceKrystalx  709884951  1054063719  168885343    1139599610  438440458
#
#       Prayer       Magic    Cooking  Woodcutting  ...      Slayer     Farming  \
# 0  167495429  1235133936  148431608    141694702  ...  1280489665  1145339197
#
#    Runecrafting     Hunter  Construction  Summmoning  Dungeoneering  \
# 0     136534895  142332293     153621208   192895420     2000000000
#
#    Divination  Invention  Archaeology
# 0   142876467  933745357   1163031646
#
# [1 rows x 29 columns]

# %%
players = []

with open('players.csv', newline='') as csvfile:

    reader = csv.DictReader(csvfile)

    for row in reader:

        print(row['Name'])
        players.append(row['Name'])


players
# Out:
# MyFinestDays
# jothela
# Trimmed
# Icekro
# IceKrystalx
# Sticky Pears
# Sheivot
# Fireboy509
# Drizzt Wrath
# Iv99roidmage
# gision
# Aczinor9
# Glacyte
# Raime
# Cerene
# Mechchaser0
# Hera Selene
# eMaG dNiM
# Clifloku
# X1 Noodle
# wahtdaef
# Mitsyangel
# FrogHam
# EllieRoses
# Tigervu
# Madhura01
# iLuthonic
# Deathmall
# garh1993
# MaleficentMe
# Crideceon
# VaticanCameo
# tuskawraith
# Hamuod
# Foreverr420
# LethalSeraph
# Hayki
# CorruptVicar
# ZeroArcanist
# SpeedRacerX1
# Alhifar
# Daretoachv
# Lilo Kuo
# EazyUK
# Iristelessa
# ETK ThotGod
# Warnch
# ETK Br34an
# HisKageness
# Matti K
# N E R V
# SteakAndEggs
# Gunmaster422
# SkillerJay03
# Rubin McLit
# ETK Onyx
# Austiin
# AshNicTay
# Ben7196
# Im Just Fat
# Andalusia
# Packaging
# Vivia
# eMaG NoRi
# Bumo
# Seshomarou
# Jyxxe
# Lord Mager
# Hey Cheyenne
# cerene1
# Kaezarh
# Brazinx69
# Buying IRLGF
# MiniCraz
# Combustive
# ETK Brisingr
# Osva Labas
# Zorrezias
# D Wrath Jr
# ETK Panda
# Reaper Joe
# PandaDudes
# ...
